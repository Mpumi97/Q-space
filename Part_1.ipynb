# %% [markdown]
# <a href="https://colab.research.google.com/github/Mpumi97/Q-space/blob/main/Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Bioinformatics - Drug Discovery Project

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      |████████████████████████████████| 55 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 10.6 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.0.1 which is incompatible.
# ...

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ### Search for Target protein

# %%
#Target protein for coronavirus

target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  ...   tax_id
# 0                                                 []  ...    11119
# 1                                                 []  ...   227859
# 2                                                 []  ...    12663
# 3                                                 []  ...    11137
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...  ...   227859
# 5                                                 []  ...  1335626
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...  ...   227859
# 7                                                 []  ...  2697049
#
# [8 rows x 9 columns]

# %% [markdown]
# ### Select and retrieve bioactivity data for SARS coronavirus 3C-like proteinase

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL3927'

# %% [markdown]
# Here we will retrieve only bioactivity data from SARS coronavirus 3C-like proteinase (CHEMBL3927) that are reported as $IC_{50}$ values in nM unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id = selected_target).filter(standard_type = 'IC50')

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head()
# Out:
#   activity_comment  activity_id  ... upper_value  value
# 0             None      1480935  ...        None    7.2
# 1             None      1480936  ...        None    9.4
# 2             None      1481061  ...        None   13.5
# 3             None      1481065  ...        None  13.11
# 4             None      1481066  ...        None    2.0
#
# [5 rows x 45 columns]

# %%
df['standard_type'].unique()
# Out:
# array(['IC50'], dtype=object)

# %%
#Finally we save our bioactivity data to a csv file called bioactivity_data.csv

df.to_csv('bioactivity_data.csv', index = False)

# %% [markdown]
# ## Handling of Missing Data
#
# if any compounds has missing value for the standard value then drop it.

# %%
df2 = df[df['standard_value'].notna()]

# %%
df2.head()
# Out:
#   activity_comment  activity_id  ... upper_value  value
# 0             None      1480935  ...        None    7.2
# 1             None      1480936  ...        None    9.4
# 2             None      1481061  ...        None   13.5
# 3             None      1481065  ...        None  13.11
# 4             None      1481066  ...        None    2.0
#
# [5 rows x 45 columns]

# %% [markdown]
# ## Data preprocessing for the bioactivity data
#
# The bioactivity data is in the IC50 unit. Compunds having
# - standard_value < 1000 : active
# - standard_value > 10000 : inactive
# - 1000<=standard_value<=10000: intermediate

# %%
bioactivity_class = []

for i in df2['standard_value']:
  if float(i) >= 10000:
    bioactivity_class.append('Inactive')
  elif float(i) <= 1000:
    bioactivity_class.append('Active')
  else:
    bioactivity_class.append('Intermediate')

# %%
bioactivity_class
# Out:
# ['Intermediate',
#  'Intermediate',
#  'Inactive',
#  'Inactive',
#  'Intermediate',
#  'Active',
#  'Intermediate',
#  'Active',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Active',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Intermediate',
#  'Inactive',
#  'Inactive',
#  'Intermediate',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
#  'Inactive',
# ...

# %%
df2['molecule_chembl_id']
# Out:
# 0       CHEMBL187579
# 1       CHEMBL188487
# 2       CHEMBL185698
# 3       CHEMBL426082
# 4       CHEMBL187717
#            ...
# 128    CHEMBL2146517
# 129     CHEMBL187460
# 130     CHEMBL363535
# 131     CHEMBL227075
# 132      CHEMBL45830
# Name: molecule_chembl_id, Length: 133, dtype: object

# %%
mol_cid = []

for i in df2['molecule_chembl_id']:
  mol_cid.append(i)

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']

# %%
df_sel = df2[selection]
df_sel
# Out:
#     molecule_chembl_id  ... standard_value
# 0         CHEMBL187579  ...         7200.0
# 1         CHEMBL188487  ...         9400.0
# 2         CHEMBL185698  ...        13500.0
# 3         CHEMBL426082  ...        13110.0
# 4         CHEMBL187717  ...         2000.0
# ..                 ...  ...            ...
# 128      CHEMBL2146517  ...        10600.0
# 129       CHEMBL187460  ...        10100.0
# 130       CHEMBL363535  ...        11500.0
# 131       CHEMBL227075  ...        10700.0
# 132        CHEMBL45830  ...        78900.0
#
# [133 rows x 3 columns]

# %%
df3 = pd.concat([df_sel, pd.Series(bioactivity_class)],axis =1)

# %%
df3
# Out:
#     molecule_chembl_id  ...             0
# 0         CHEMBL187579  ...  Intermediate
# 1         CHEMBL188487  ...  Intermediate
# 2         CHEMBL185698  ...      Inactive
# 3         CHEMBL426082  ...      Inactive
# 4         CHEMBL187717  ...  Intermediate
# ..                 ...  ...           ...
# 128      CHEMBL2146517  ...      Inactive
# 129       CHEMBL187460  ...      Inactive
# 130       CHEMBL363535  ...      Inactive
# 131       CHEMBL227075  ...      Inactive
# 132        CHEMBL45830  ...      Inactive
#
# [133 rows x 4 columns]

# %%
df3.rename(columns={0:'bioactivity_class'}, inplace = True)

# %%
df3
# Out:
#     molecule_chembl_id  ... bioactivity_class
# 0         CHEMBL187579  ...      Intermediate
# 1         CHEMBL188487  ...      Intermediate
# 2         CHEMBL185698  ...          Inactive
# 3         CHEMBL426082  ...          Inactive
# 4         CHEMBL187717  ...      Intermediate
# ..                 ...  ...               ...
# 128      CHEMBL2146517  ...          Inactive
# 129       CHEMBL187460  ...          Inactive
# 130       CHEMBL363535  ...          Inactive
# 131       CHEMBL227075  ...          Inactive
# 132        CHEMBL45830  ...          Inactive
#
# [133 rows x 4 columns]

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index = False)

# %% [markdown]
# ### Exploratory Data Analysis
